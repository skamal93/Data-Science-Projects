# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
churn=pd.read_csv("Customer Churn.csv")

# %%
churn.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn.groupby("Churn").size().plot(kind="pie")
plt.title("Customer Churn Rate")
# Out:
# Text(0.5, 1.0, 'Customer Churn Rate')

# %%
churn["Contract"].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
churn_cust=churn[churn["Churn"]=="Yes"]
non_churn=churn[churn["Churn"]=="No"]

# %%
churn_cust.describe(include="all")
# Out:
#         customerID  gender  SeniorCitizen Partner Dependents       tenure  \
# count         1869    1869    1869.000000    1869       1869  1869.000000
# unique        1869       2            NaN       2          2          NaN
# top     3753-TSEMP  Female            NaN      No         No          NaN
# freq             1     939            NaN    1200       1543          NaN
# mean           NaN     NaN       0.254682     NaN        NaN    17.979133
# std            NaN     NaN       0.435799     NaN        NaN    19.531123
# min            NaN     NaN       0.000000     NaN        NaN     1.000000
# 25%            NaN     NaN       0.000000     NaN        NaN     2.000000
# 50%            NaN     NaN       0.000000     NaN        NaN    10.000000
# 75%            NaN     NaN       1.000000     NaN        NaN    29.000000
# max            NaN     NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
non_churn.describe(include="all")
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         5174   5174    5174.000000    5174       5174  5174.000000
# unique        5174      2            NaN       2          2          NaN
# top     3724-BSCVH   Male            NaN     Yes         No          NaN
# freq             1   2625            NaN    2733       3390          NaN
# mean           NaN    NaN       0.128721     NaN        NaN    37.569965
# std            NaN    NaN       0.334923     NaN        NaN    24.113777
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN    15.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    38.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    61.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
sns.barplot(x="Churn",y="tenure",data=churn)
plt.title("Tenure Data according to Churn")
# Out:
# Text(0.5, 1.0, 'Tenure Data according to Churn')

# %%
phone_ser=pd.crosstab(churn["Churn"],churn["PhoneService"],normalize="index").plot(kind="bar")
plt.title("Phone service effect on Churn Rate")
# Out:
# Text(0.5, 1.0, 'Phone service effect on Churn Rate')

# %%
mulin=pd.crosstab(churn["Churn"],churn["MultipleLines"],normalize="index").plot(kind="bar")
#plt.title("Lines effect on Churn Rate")
mulin

# %%
mulin=pd.crosstab(churn["Churn"],churn["MultipleLines"],normalize="index").plot(kind="bar")

# %%
churn=pd.get_dummies(churn,columns=[ 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn'])

# %%
churn.head(5)
# Out:
#    customerID  MonthlyCharges TotalCharges  gender_Female  gender_Male  \
# 0  7590-VHVEG           29.85        29.85              1            0
# 1  5575-GNVDE           56.95       1889.5              0            1
# 2  3668-QPYBK           53.85       108.15              0            1
# 3  7795-CFOCW           42.30      1840.75              0            1
# 4  9237-HQITU           70.70       151.65              1            0
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0                1                0           0            1              1
# 1                1                0           1            0              1
# 2                1                0           1            0              1
# 3                1                0           1            0              1
# 4                1                0           1            0              1
#
#    ...  Contract_One year  Contract_Two year  PaperlessBilling_No  \
# ...
