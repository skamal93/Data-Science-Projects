# %% [raw]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa_20=pd.read_csv("players_20.csv")
fifa_20.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa_20.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# std        6.139669  5.585481e+06   21351.714095                  0.378861
# min       49.000000  0.000000e+00       0.000000                  1.000000
# 25%       67.000000  3.250000e+05    1000.000000                  1.000000
# 50%       71.000000  7.000000e+05    3000.000000                  1.000000
# 75%       75.000000  2.100000e+06    8000.000000                  1.000000
# max       95.000000  1.055000e+08  565000.000000                  5.000000
#
#           weak_foot  ...  mentality_penalties  mentality_composure  \
# count  18278.000000  ...         18278.000000         18278.000000
# mean       2.944250  ...            48.383357            58.528778
# std        0.664656  ...            15.708099            11.880840
# min        1.000000  ...             7.000000            12.000000
# 25%        3.000000  ...            39.000000            51.000000
# 50%        3.000000  ...            49.000000            60.000000
# 75%        3.000000  ...            60.000000            67.000000
# max        5.000000  ...            92.000000            96.000000
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# count       18278.000000               18278.000000              18278.000000
# mean           46.848889                  47.640333                 45.606631
# std            20.091287                  21.585641                 21.217734
# min             1.000000                   5.000000                  3.000000
# 25%            29.000000                  27.000000                 24.000000
# 50%            52.000000                  55.000000                 52.000000
# 75%            64.000000                  66.000000                 64.000000
# max            94.000000                  92.000000                 90.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        18278.000000          18278.000000         18278.000000
# mean            16.572765             16.354853            16.212934
# std             17.738069             16.996925            16.613665
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             90.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes
# count             18278.000000          18278.000000
# mean                 16.368038             16.709924
# std                  17.136497             18.038125
# min                   1.000000              1.000000
# 25%                   8.000000              8.000000
# 50%                  11.000000             11.000000
# 75%                  14.000000             14.000000
# max                  91.000000             92.000000
#
# [8 rows x 61 columns]

# %%
fifa_20.loc[0,'wage_eur']
# Out:
# 565000

# %%
club_average_salary=fifa_20.groupby("club").wage_eur.mean().sort_values(ascending=False)
club_average_salary
# Out:
# club
# Real Madrid          162242.424242
# FC Barcelona         150000.000000
# Manchester City      120727.272727
# Juventus             113636.363636
# FC Bayern München    109391.304348
#                          ...
# Romania                   0.000000
# Cameroon                  0.000000
# Finland                   0.000000
# Colombia                  0.000000
# Wales                     0.000000
# Name: wage_eur, Length: 698, dtype: float64

# %%
club_average_salary.loc["Chelsea"]
#This line finds out the average salary levels at Chelsea
# Out:
# 85030.30303030302

# %%
# %matplotlib inline
y=fifa_20[fifa_20["overall"]>70]
plt.scatter(y["overall"],y["wage_eur"],color="green")
#This code checks how the overall is related to the wage rates at FIFA 20

# %%
striker=fifa_20[fifa_20["player_positions"].str.contains("ST")]
st_salary=striker.wage_eur.mean()
striker
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 9         209331  https://sofifa.com/player/209331/mohamed-salah...
# 10        231747  https://sofifa.com/player/231747/kylian-mbappe...
# 12        202126  https://sofifa.com/player/202126/harry-kane/20...
# ...          ...                                                ...
# 18243     247100  https://sofifa.com/player/247100/elliott-sarto...
# 18249     233667  https://sofifa.com/player/233667/huanhuan-shan...
# 18250     238550  https://sofifa.com/player/238550/rowan-roache/...
# 18254     251269  https://sofifa.com/player/251269/emil-jaaskela...
# 18261     238521  https://sofifa.com/player/238521/haruto-shirai...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 9               M. Salah                 Mohamed  Salah Ghaly   27
# 10             K. Mbappé                        Kylian Mbappé   20
# 12               H. Kane                           Harry Kane   25
# ...                  ...                                  ...  ...
# 18243       E. Sartorius                    Elliott Sartorius   16
# 18249      Shan Huanhuan                                  单欢欢   20
# 18250          R. Roache                         Rowan Roache   19
# 18254    E. Jääskeläinen                    Emil Jääskeläinen   18
# 18261          H. Shirai                                白井 陽斗   19
#
#               dob  height_cm  weight_kg          nationality  \
# 0      1987-06-24        170         72            Argentina
# 1      1985-02-05        187         83             Portugal
# 9      1992-06-15        175         71                Egypt
# 10     1998-12-20        178         73               France
# 12     1993-07-28        188         89              England
# ...           ...        ...        ...                  ...
# 18243  2002-07-29        174         69              England
# 18249  1999-01-24        185         75             China PR
# 18250  2000-02-09        178         74  Republic of Ireland
# 18254  2001-03-16        183         66              Finland
# 18261  1999-10-23        170         60                Japan
#
#                       club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 0             FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2  52+2
# 1                 Juventus  ...  65+3  61+3  61+3  61+3  65+3  61+3  53+3
# 9                Liverpool  ...  70+3  67+3  67+3  67+3  70+3  66+3  57+3
# 10     Paris Saint-Germain  ...  66+3  62+3  62+3  62+3  66+3  63+3  54+3
# 12       Tottenham Hotspur  ...  65+3  66+3  66+3  66+3  65+3  62+3  60+3
# ...                    ...  ...   ...   ...   ...   ...   ...   ...   ...
# 18243         Lincoln City  ...  33+2  30+2  30+2  30+2  33+2  32+2  27+2
# 18249     Dalian YiFang FC  ...  37+2  36+2  36+2  36+2  37+2  37+2  35+2
# 18250            Blackpool  ...  32+2  29+2  29+2  29+2  32+2  30+2  27+2
# 18254            Blackpool  ...  35+2  32+2  32+2  32+2  35+2  33+2  28+2
# 18261          Gamba Osaka  ...  34+2  30+2  30+2  30+2  34+2  33+2  28+2
#
#          cb   rcb    rb
# 0      52+2  52+2  63+2
# 1      53+3  53+3  61+3
# 9      57+3  57+3  66+3
# 10     54+3  54+3  63+3
# 12     60+3  60+3  62+3
# ...     ...   ...   ...
# 18243  27+2  27+2  32+2
# 18249  35+2  35+2  37+2
# 18250  27+2  27+2  30+2
# 18254  28+2  28+2  33+2
# 18261  28+2  28+2  33+2
#
# [3255 rows x 104 columns]

# %%
gk=fifa_20[fifa_20["player_positions"].str.contains("GK")]
gk_salary=gk.wage_eur.mean()
sal_dif=st_salary-gk_salary
sal_dif
# Out:
# 3944.3123621208424

# %%
fifa_20["difference"]=fifa_20["potential"]-fifa_20["overall"]
player_name=fifa_20[fifa_20["difference"]==max(fifa_20["difference"])]
player_name
# Out:
#        sofifa_id                                         player_url  \
# 15327     243585  https://sofifa.com/player/243585/gavin-bazunu/...
# 16717     252072  https://sofifa.com/player/252072/santiago-ramo...
# 17077     243353  https://sofifa.com/player/243353/bali-mumba/20...
# 18169     246313  https://sofifa.com/player/246313/slavi-spasov/...
# 18235     248376  https://sofifa.com/player/248376/qianglong-tao...
# 18236     252890  https://sofifa.com/player/252890/brandon-mcphe...
#
#            short_name             long_name  age         dob  height_cm  \
# 15327       G. Bazunu          Gavin Bazunu   17  2002-02-20        188
# 16717  S. Ramos Mingo  Santiago Ramos Mingo   17  2001-11-21        185
# 17077        B. Mumba            Bali Mumba   17  2001-10-08        163
# 18169       S. Spasov          Slavi Spasov   17  2001-12-31        171
# 18235   Tao Qianglong                   陶强龙   17  2001-11-20        172
# 18236    B. McPherson     Brandon McPherson   17  2002-02-02        178
#
#        weight_kg          nationality                    club  ...   ldm  \
# 15327         73  Republic of Ireland         Manchester City  ...   NaN
# 16717         74            Argentina            Boca Juniors  ...  48+2
# 17077         57              England              Sunderland  ...  55+2
# 18169         56             Bulgaria           Oxford United  ...  31+2
# 18235         65             China PR  Hebei China Fortune FC  ...  30+2
# 18236         75              England            Grimsby Town  ...  35+2
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb difference
# 15327   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN         25
# 16717  48+2  48+2  49+2  52+2  55+2  55+2  55+2  52+2         25
# 17077  55+2  55+2  54+2  54+2  54+2  54+2  54+2  54+2         25
# 18169  31+2  31+2  33+2  32+2  27+2  27+2  27+2  32+2         25
# 18235  30+2  30+2  34+2  32+2  29+2  29+2  29+2  32+2         25
# 18236  35+2  35+2  39+2  38+2  32+2  32+2  32+2  38+2         25
#
# [6 rows x 105 columns]

# %%
a=striker.corr()["overall"]
b=a.loc[["attacking_finishing","attacking_crossing","skill_dribbling"]]
b
# Out:
# attacking_finishing    0.881682
# attacking_crossing     0.594756
# skill_dribbling        0.808209
# Name: overall, dtype: float64

# %%
bm_players=fifa_20[fifa_20["club"]=="FC Barcelona"]

# %%
bm_players.nationality.value_counts()
# Out:
# Spain          15
# France          5
# Brazil          3
# Netherlands     2
# Portugal        1
# Senegal         1
# Uruguay         1
# Argentina       1
# Chile           1
# Croatia         1
# Germany         1
# Japan           1
# Name: nationality, dtype: int64

# %%
# Out:
# 8
